# %%
import pandas as pd

df = pd.read_csv('titanic.csv')
print(df)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
#--->a) El Histograma de frecuencias para la variable edad

import matplotlib.pyplot as plt
hg, ax = plt.subplots()
ax.hist(df["Age"]) 
ax.set_xlabel("EDADES")
ax.set_ylabel("TOTALES")
plt.show()

# %%
hg.savefig('histograma.jpg', dpi=150)

# %%
#--->b) El diagrama de caja para la variable edad

import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.boxplot([df["Age"]])   
ax.set_xticklabels(["Edad"])
ax.set_ylabel("Años")
plt.show()

# %%
fig.savefig('diagrama_caja.jpg', dpi=150)

# %%
#--->c) Un gráfico que muestre el número de pasajeros de cada clase (variable “Pclass”)

import pandas as pd
import matplotlib.pyplot as plt




data = pd.read_csv('titanic.csv')


passenger_count_by_class = data['Pclass'].value_counts().sort_index()

# Crear el gráfico de barras
plt.bar(passenger_count_by_class.index, passenger_count_by_class.values)
plt.xlabel('Clase')
plt.ylabel('Número de Pasajeros')
plt.title('Número de Pasajeros por Clase en el Titanic')
plt.xticks(passenger_count_by_class.index)
plt.savefig('grafico_titanic.jpg',  dpi=150)  #---> esta instrucción me da la imagen externa
plt.show()
